# %% [markdown]
# ## Importing libraries

# %%
# Standard library imports
import os
import sys
import json
import random
from collections import OrderedDict

# Third-party library imports
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim.lr_scheduler import CosineAnnealingLR
from torch.utils.data import Dataset, DataLoader, Subset
import torchvision
import torchvision.transforms as transforms
from torchvision import datasets, models
from PIL import Image
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Save Checkpoint

# %%
import os
import torch
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)



DIR_DATA = "./data"

from google.colab import drive
drive.mount('/content/drive')

# Create a Folder in the root directory
# !mkdir -p "/content/drive/My Drive/My Folder/checkpoints_contrib"

CHECKPOINT_DIR = '/content/drive/My Drive/My Folder/checkpoints_contrib'

os.makedirs(CHECKPOINT_DIR, exist_ok=True)

os.makedirs(CHECKPOINT_DIR, exist_ok=True)

def save_checkpoint(model, optimizer, epoch, hyperparameters, subfolder="", data_to_save=None):
    """Salva il checkpoint del modello e rimuove quello precedente."""
    subfolder_path = os.path.join(CHECKPOINT_DIR, subfolder)
    os.makedirs(subfolder_path, exist_ok=True)

    # File corrente e precedente
    filename = f"model_epoch_{epoch}_params_{hyperparameters}.pth"
    filepath = os.path.join(subfolder_path, filename)
    filename_json = f"model_epoch_{epoch}_params_{hyperparameters}.json"
    filepath_json = os.path.join(subfolder_path, filename_json)


    previous_filename = f"model_epoch_{epoch -10}_params_{hyperparameters}.pth"
    previous_filepath = os.path.join(subfolder_path, previous_filename)
    previous_filename_json = f"model_epoch_{epoch -10}_params_{hyperparameters}.json"
    previous_filepath_json = os.path.join(subfolder_path, previous_filename_json)

    # Rimuove il checkpoint precedente
    if epoch > 1 and os.path.exists(previous_filepath) and os.path.exists(previous_filepath_json):
        os.remove(previous_filepath)
        os.remove(previous_filepath_json)

    # Salva il nuovo checkpoint
    if optimizer is not None:
        torch.save({
            'model_state_dict': model.state_dict(),
            'optimizer_state_dict': optimizer.state_dict(),  # Salvataggio dello stato dell'ottimizzatore
            'epoch': epoch
        }, filepath)
    else:
        torch.save({
            'model_state_dict': model.state_dict(),
            'epoch': epoch
        }, filepath)
    print(f"Checkpoint salvato: {filepath}")

    with open(filepath_json, 'w') as json_file:
      json.dump(data_to_save, json_file, indent=4)


def load_checkpoint(model, optimizer, hyperparameters, subfolder=""):
    """Carica l'ultimo checkpoint disponibile basato sugli iperparametri."""
    subfolder_path = os.path.join(CHECKPOINT_DIR, subfolder)
    if not os.path.exists(subfolder_path):
        print("No checkpoint found, Starting now...")
        return 1, None  # Le epoche iniziano da 1

    # Cerca i file con gli iperparametri specificati
    files = [f for f in os.listdir(subfolder_path) if f"params_{hyperparameters}" in f and f.endswith('.pth')]
    if files:
        # Trova il file con l'epoca più alta
        latest_file = max(files, key=lambda x: int(x.split('_')[2]))
        filepath = os.path.join(subfolder_path, latest_file)
        checkpoint = torch.load(filepath)

        model.load_state_dict(checkpoint['model_state_dict'])
        if optimizer is not None:
            optimizer.load_state_dict(checkpoint['optimizer_state_dict'])

        # Trova e carica il file JSON associato
        json_filename = latest_file.replace('.pth', '.json')
        json_filepath = os.path.join(subfolder_path, json_filename)
        json_data = None
        if os.path.exists(json_filepath):
            with open(json_filepath, 'r') as json_file:
                json_data = json.load(json_file)
            print(f"JSON data loaded: {json_filepath}")
        else:
            print(f"No JSON file found for: {latest_file}")

        print(f"Checkpoint found: Resume epoch {checkpoint['epoch'] + 1}")
        return checkpoint['epoch'] + 1, json_data

    print("No checkpoint found, Starting now...")
    return 1, None  # Le epoche iniziano da 1
# Out:
# Mounted at /content/drive

# %%
import random

def generate_skewed_array(target_sum, num_elements, skew_factor=0):
    """
    Generate an array of integers that sum up to a target value.

    Args:
        target_sum (int): The target sum of the array.
        num_elements (int): The number of elements in the array.
        skew_factor (float): A positive skew factor favors smaller numbers,
                             a negative skew factor favors larger numbers,
                             and 0 results in an approximately uniform distribution.

    Returns:
        list: An array of integers summing up to the target value.
    """
    if num_elements <= 0:
        raise ValueError("num_elements must be greater than 0")

    # Generate a distribution using Dirichlet
    alpha = [1 + skew_factor] * num_elements if skew_factor >= 0 else [1 - skew_factor] * num_elements
    raw_weights = np.random.dirichlet(alpha)

    # Scale weights to the target sum
    scaled_weights = raw_weights * target_sum

    # Convert to integers while keeping track of the fractional parts
    integer_parts = np.floor(scaled_weights).astype(int)
    fractional_parts = scaled_weights - integer_parts

    # Adjust the result to ensure the sum matches the target_sum
    diff = target_sum - np.sum(integer_parts)

    # Distribute the difference based on the largest fractional parts
    fractional_indices = np.argsort(-fractional_parts)
    for i in range(abs(diff)):
        integer_parts[fractional_indices[i]] += 1 if diff > 0 else -1

    return integer_parts.tolist()

def generate_vector(target_sum, n):
    """
    Generates a vector (list) with n positive elements that sum to target_sum.
    Used for niid sharding

    Parameters:
    - target_sum: The desired sum of the vector elements.
    - n: The number of elements in the vector.

    Returns:
    - A list of n positive elements that sum to target_sum.
    """
    if target_sum < n:
        raise ValueError("Target sum must be at least equal to the number of elements to ensure all elements are positive.")

    # Create n random weights that sum to 1
    weights = [random.random() for _ in range(n)]
    total_weight = sum(weights)
    normalized_weights = [w / total_weight for w in weights]

    # Scale the weights to sum to the target_sum
    vector = [max(1, int(target_sum * w)) for w in normalized_weights]

    # Adjust to ensure the exact sum of target_sum
    current_sum = sum(vector)
    while current_sum != target_sum:
        # Find the difference between the current sum and the target sum
        difference = target_sum - current_sum

        # Adjust a random element to fix the difference
        index_to_adjust = random.randint(0, n - 1)
        if difference > 0:
            vector[index_to_adjust] += 1
        elif vector[index_to_adjust] > 1:  # Ensure no element goes below 1
            vector[index_to_adjust] -= 1

        # Recalculate the sum
        current_sum = sum(vector)

    return vector


# Example usage
l = generate_skewed_array(target_sum=50000, num_elements=100, skew_factor=0)
print(l)
print(sum(l))
# Out:
# [256, 1645, 720, 499, 93, 93, 33, 1099, 502, 673, 11, 1915, 976, 130, 110, 111, 198, 407, 309, 188, 517, 82, 189, 249, 333, 841, 122, 395, 491, 26, 511, 102, 37, 1625, 1842, 903, 199, 56, 630, 317, 71, 374, 19, 1312, 164, 594, 204, 401, 432, 112, 1909, 816, 1533, 1231, 498, 1394, 51, 119, 25, 215, 269, 173, 964, 241, 180, 428, 83, 886, 42, 2369, 809, 121, 3, 924, 671, 714, 806, 42, 243, 67, 1087, 534, 220, 36, 204, 215, 715, 555, 1193, 349, 70, 683, 782, 450, 806, 372, 404, 305, 14, 62]
# 50000

# %% [markdown]
# # CIFAR100 Dataset

# %%
class CIFAR100Dataset(Dataset):
    def __init__(self, root, split='train', transform=None, sharding=None, K=10, Nc=2, skewed_factor = None):
        """
        CIFAR-100 Dataset with IID and non-IID sharding.

        Args:
        - root (str): Directory to store the dataset.
        - split (str): 'train' or 'test'.
        - transform (callable): Transformations applied to the images.
        - sharding (str): 'iid' or 'niid'.
        - K (int): Number of clients for the sharding.
        - Nc (int): Number of classes per client (used for non-iid sharding).
        """
        self.root = root
        self.split = split
        self.transform = transform
        self.sharding = sharding
        self.K = K
        self.Nc = Nc


        # Default transformations if none are provided
        if self.transform is None:
            if self.split == 'train':
                self.transform = transforms.Compose([
                    transforms.RandomHorizontalFlip(),  # Flip orizzontale casuale
                    transforms.RandomRotation(10),
                    transforms.ToTensor(),  # Converte l'immagine in un tensore PyTorch
                    transforms.Normalize(mean=[0.5071, 0.4865, 0.4409], std=[0.2673, 0.2564, 0.2762]),  # Normalizzazione
                ])
            else:
                self.transform = transforms.Compose([
                    transforms.ToTensor(),  # Converte in tensore PyTorch
                    transforms.Normalize(mean=[0.5071, 0.4865, 0.4409], std=[0.2673, 0.2564, 0.2762]),  # Normalizzazione
                ])

        dataset = datasets.CIFAR100(
            root=self.root,
            train=(self.split == 'train'),
            download=True
        )

        self.data = pd.DataFrame({
            "image": [dataset[i][0] for i in range(len(dataset))],
            "label": [dataset[i][1] for i in range(len(dataset))]
        })

        if self.split == 'train' and self.sharding:
            self.data = self._apply_sharding()

    def _apply_sharding(self):
        """Apply IID or non-IID sharding to the training data."""
        if self.sharding == 'iid':
            return self._iid_sharding()
        elif self.sharding == 'niid':
            return self._non_iid_sharding()
        elif self.sharding == 'eniid':
            return self._extreme_non_iid_sharding()
        else:
            raise ValueError("Sharding must be 'iid' or 'niid'.")

    def _iid_sharding(self):
        """Split data IID: uniformly distribute samples across K clients."""
        data_split = []
        indices = self.data.index.tolist()
        random.shuffle(indices)

        # Split indices equally among K clients
        client_indices = [indices[i::self.K] for i in range(self.K)]

        for client_id, idxs in enumerate(client_indices):
            client_data = self.data.loc[idxs].copy()
            client_data['client_id'] = client_id
            data_split.append(client_data)

        return pd.concat(data_split, ignore_index=True)

    def _non_iid_sharding(self):
      """Non-IID sharding with fixed number of classes per client"""
      data_split = []
      labels = self.data['label'].unique()
      samples_per_client = generate_skewed_array(len(self.data), self.K)

      for client_id in range(self.K):
          # Seleziona Nc classi casuali per questo client
          client_classes = np.random.choice(labels, size=self.Nc, replace=False)

          # Ottieni il numero totale di campioni per il client
          total_samples = samples_per_client[client_id]

          # Assicurati che il numero totale di campioni sia sufficiente per il numero di classi
          min_samples_per_class = 5  # Numero minimo di campioni per classe
          total_samples = max(total_samples, min_samples_per_class * len(client_classes))

          # Distribuisci i campioni tra le classi
          samples_per_class = generate_vector(total_samples, len(client_classes))

          client_data = pd.DataFrame()
          for idx, class_ in enumerate(client_classes):
              class_data = self.data[self.data['label'] == class_]
              samples = class_data.sample(n=samples_per_class[idx], replace=True)  # replace=False per evitare duplicati
              client_data = pd.concat([client_data, samples])

          client_data['client_id'] = client_id
          data_split.append(client_data)

      # Concatenate tutti i dati per avere il dataset completo per tutti i clienti
      all_data = pd.concat(data_split, ignore_index=True)
      return all_data

    def _extreme_non_iid_sharding(self):
        """Extreme Non-IID sharding with a random number of samples per client."""
        data_split = []
        indexes = self.data.index.tolist()
        random.shuffle(indexes)  # Shuffle the dataset indices

        start_idx = 0
        samples_per_client = generate_skewed_array(len(self.data), self.K, skew_factor=0)

        for client_id, num_samples in enumerate(samples_per_client):
            # Select num_samples samples for this client
            end_idx = start_idx + num_samples
            client_data = self.data.iloc[start_idx:end_idx].copy()
            client_data['client_id'] = client_id
            data_split.append(client_data)

            # Update the start index for the next client
            start_idx = end_idx

        # Concatenate all the client data into a single DataFrame
        all_data = pd.concat(data_split, ignore_index=True)
        return all_data



    def __getitem__(self, index):
        row = self.data.iloc[index]
        image, label = row['image'], row['label']

        if self.transform:
            image = self.transform(image)
        return image, label

    def __len__(self):
        return len(self.data)

# %% [markdown]
# ## LeNet-5

# %%
class LeNet5(nn.Module):
    def __init__(self,num_classes=100):
        super(LeNet5, self).__init__()
        self.conv_layer = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=5),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(64, 64, kernel_size=5),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        self.fc_layer = nn.Sequential(
            nn.Linear(64 * 5 * 5, 384),  # Updated to be consistent with data augmentation
            nn.ReLU(),
            nn.Linear(384, 192),
            nn.ReLU(),
            nn.Linear(192, num_classes)  # 100 classes for CIFAR-100
        )

    def forward(self, x):
        x = self.conv_layer(x)
        x = x.view(x.size(0), -1)  # Flatten the output of the conv layers
        x = self.fc_layer(x)
        x = F.log_softmax(x, dim=1)
        return x

# %% [markdown]
# # Evaluation of CIFAR100

# %%
def evaluate_model(model, validation_loader, criterion, device):
    model.eval()
    total_loss = 0
    correct = 0
    total = 0

    with torch.no_grad():
        for inputs, targets in validation_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            total_loss += loss.item()
            _, predicted = outputs.max(1)
            correct += (predicted == targets).sum().item()
            total += targets.size(0)

    return total_loss / len(validation_loader), correct / total

# %% [markdown]
# ## FL classes

# %%
def plot_selected_clients_distribution(selected_clients_per_round, num_clients, hyperparameters):
    """Plotta la distribuzione dei client selezionati alla fine del processo."""
    counts = np.zeros(num_clients)

    # Conta quante volte ogni client è stato selezionato in tutti i round
    for selected_clients in selected_clients_per_round:
        for client in selected_clients:
            counts[client] += 1

    plt.figure(figsize=(10, 6))
    plt.bar(range(num_clients), counts, color='skyblue', edgecolor='black')
    plt.title("Distribuzione dei Client Selezionati Durante il Federated Averaging")
    plt.xlabel("Client ID")
    plt.ylabel("Frequenza di Selezione")
    plt.grid(axis='y')
    plt.savefig(f"CIFAR100_Client_distribution_{hyperparameters}.png")
    plt.show()


class Client:

  def __init__(self, model, client_id, data, optimizer_params):
    self.client_id = client_id
    self.data = data
    self.model = model
    self.optimizer_params = optimizer_params

  def train(self, global_weights, local_steps, batch_size):
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    self.model.to(device)
    self.model.load_state_dict(global_weights)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(
        self.model.parameters(),
        lr=self.optimizer_params['lr'],
        momentum=self.optimizer_params['momentum'],
        weight_decay=self.optimizer_params['weight_decay']
        )
    trainloader = DataLoader(self.data, batch_size=batch_size, shuffle=True,  pin_memory=True)

    steps = 0
    while steps < local_steps:
      for batch_idx, (inputs, targets) in enumerate(trainloader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = self.model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        steps += 1
        if steps >= local_steps:
          break
    return self.model.state_dict()

# %%
class Server:

  def __init__(self, model, clients, test_data, val_data):
    self.model = model
    self.clients = clients
    self.val_data = val_data
    self.test_data = test_data
    self.round_losses = []
    self.round_accuracies = []
    self.selected_clients_per_round = [] #clint selezionati per skewness
    self.test_losses = []
    self.test_accuracies = []


  def client_selection(self, num_clients, fraction, probabilities=None):
      "It selects a subset of clients based on uniform or skewed distribution"
      num_clients_to_select = int(num_clients * fraction)
      if probabilities is None:
          selected_clients = np.random.choice(num_clients, num_clients_to_select, replace=False)
      else:
          selected_clients = np.random.choice(num_clients, num_clients_to_select, p=probabilities, replace=False)
      return selected_clients

  def evaluate_clients(self):
    """
    Evaluate clients using an entropy-based approach.
    Clients with more diverse data distributions are prioritized.
    Returns:
        Probabilities favoring clients with diverse data and larger datasets.
    """
    # Assumendo che client.data sia un elenco di tuple (immagine, etichetta)
    #conto numero occorrenze di ogni etichetta
    data_distributions = [
        np.bincount([label for _, label in client.data], minlength=100) for client in self.clients
    ]
    entropies = [-np.sum(d / np.sum(d) * np.log(d / np.sum(d) + 1e-5)) for d in data_distributions]

    # Normalize entropies
    normalized_entropies = np.array(entropies) / np.sum(entropies)

    # Combine with data sizes
    data_sizes = [len(client.data) for client in self.clients]
    normalized_data_sizes = np.array(data_sizes) / np.sum(data_sizes)

    # Combine metrics
    alpha = 0.7  # Weight for entropy
    combined_scores = alpha * normalized_entropies + (1 - alpha) * normalized_data_sizes

    # Normalize combined scores to get probabilities
    probabilities = combined_scores / np.sum(combined_scores)
    return probabilities


  def federated_averaging(self, local_steps, batch_size, num_rounds, fraction_fit, alpha = None, hyperparameters = None):

    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    self.model.to(device)
     # Carica il checkpoint se esiste
    data_to_load = None
    probabilities = None

    start_epoch, data_to_load = load_checkpoint(self.model,optimizer=None,hyperparameters=hyperparameters, subfolder="Federated_Uniform/")

    if data_to_load is not None:
      self.round_losses = data_to_load['round_losses']
      self.round_accuracies = data_to_load['round_accuracies']
      self.selected_clients_per_round = data_to_load['selected_clients_per_round']
      self.test_losses = data_to_load['test_losses']
      self.test_accuracies = data_to_load['test_accuracies']
    if alpha is not None:
      probabilities=self.evaluate_clients()

    for round in range(start_epoch, num_rounds+1):

      selected_clients = self.client_selection(len(self.clients), fraction_fit, probabilities)

      self.selected_clients_per_round.append([self.clients[client_idx].client_id for client_idx in selected_clients])

      global_weights = self.model.state_dict()

      # Simulating parallel clients training
      client_weights = {}
      for client_idx in selected_clients:
        client = self.clients[client_idx]  # Accedi all'oggetto Client usando l'indice
        client_weights[client.client_id] = client.train(global_weights, local_steps, batch_size)


      new_global_weights = {key: torch.zeros_like(value).type(torch.float32) for key, value in global_weights.items()}

      total_data_size = sum([len(self.clients[client_idx].data) for client_idx in selected_clients])
      for client_idx in selected_clients:
          client = self.clients[client_idx]  # Accedi all'oggetto Client
          scaling_factor = len(client.data) / total_data_size
          for key in new_global_weights.keys():
              new_global_weights[key] += scaling_factor * client_weights[client.client_id][key]

      # Update global model weights
      self.model.load_state_dict(new_global_weights)

      # Evaluate global model every 10 rounds
      if round % 10 == 0:
        loss, accuracy = evaluate_model(self.model, DataLoader(self.val_data, batch_size=batch_size, shuffle=False, pin_memory=True), nn.CrossEntropyLoss(), device)
        loss_test, accuracy_test = evaluate_model(self.model, DataLoader(self.test_data, batch_size=batch_size, shuffle=False, pin_memory=True), nn.CrossEntropyLoss(), device)

        self.round_losses.append(loss)
        self.round_accuracies.append(accuracy)
        self.test_losses.append(loss_test)
        self.test_accuracies.append(accuracy_test)
        print(f"Round {round}/{num_rounds} - Loss: {loss:.4f}, Accuracy: {accuracy:.4f}")

        data_to_save = {
          'round_losses': self.round_losses,
          'round_accuracies': self.round_accuracies,
          'test_losses': self.test_losses,
          'test_accuracies': self.test_accuracies,
          'selected_clients_per_round': [[client for client in round_clients] for round_clients in self.selected_clients_per_round],  # Serializziamo solo i client_id
        }

        save_checkpoint(self.model, None, round , hyperparameters, "Federated_Uniform/", data_to_save)



    #print("Evaluation on test set...")
    #loss, accuracy = evaluate_model(self.model, DataLoader(self.test_data, batch_size=batch_size, shuffle=False, pin_memory=True), nn.CrossEntropyLoss(), device)
    #print(f"Test Loss: {loss:.4f}, Test Accuracy: {accuracy:.4f}")

     # Plot dei risultati
    plt.figure(figsize=(16, 10))

        # Validation Loss
    plt.subplot(2, 2, 1)
    plt.plot(range(0, num_rounds, 10), self.round_losses, label='Validation Loss')
    plt.xlabel('Round')
    plt.ylabel('Loss')
    plt.title('Validation Loss per Round')
    plt.legend()

        # Validation Accuracy
    plt.subplot(2, 2, 2)
    plt.plot(range(0, num_rounds, 10), self.round_accuracies, label='Validation Accuracy')
    plt.xlabel('Round')
    plt.ylabel('Accuracy')
    plt.title('Validation Accuracy per Round')
    plt.legend()

    # Test Loss
    plt.subplot(2, 2, 3)
    plt.plot(range(0, num_rounds, 10), self.test_losses, label='Test Loss', color='orange')
    plt.xlabel('Round')
    plt.ylabel('Loss')
    plt.title('Test Loss per Round')
    plt.legend()

    # Test Accuracy
    plt.subplot(2, 2, 4)
    plt.plot(range(0, num_rounds, 10), self.test_accuracies, label='Test Accuracy', color='green')
    plt.xlabel('Round')
    plt.ylabel('Accuracy')
    plt.title('Test Accuracy per Round')
    plt.legend()

    plt.tight_layout()
    file_name = f"CIFAR100_fedavg_uniform_{hyperparameters}.jpg"
    plt.savefig(file_name)
    plt.show()

    plot_selected_clients_distribution(self.selected_clients_per_round, len(self.clients), hyperparameters)

# %%
K = 100 #fix
LOCAL_STEPS = 4 # J
ROUNDS = 2000
C = 0.1 #fix
BATCH_SIZE = 64
LR = 0.001
MOMENTUM = 0
WEIGHT_DECAY = 1e-4
ALPHA=0.01

optimizer_params = {
      "lr": LR,
      "momentum": MOMENTUM,
      "weight_decay": WEIGHT_DECAY
  }

model_cifar = LeNet5(100)

train_dataset_big = CIFAR100Dataset(DIR_DATA, split="train", sharding="eniid", K=K)
test_dataset = CIFAR100Dataset(DIR_DATA, split="test")

# Split training-validation
train_indices, validation_indices = train_test_split(
    range(len(train_dataset_big)), test_size=0.2, random_state=42,stratify=train_dataset_big.data["label"]
)

# Subset di training e validazione
train_dataset = Subset(train_dataset_big, train_indices)
validation_dataset = Subset(train_dataset_big, validation_indices)

# Mapping degli indici
original_to_subset = {original_idx: subset_idx for subset_idx, original_idx in enumerate(train_indices)}

# Creazione dei client
clients = []
for i in range(K):
    # Filtra gli indici dei client dal dataset originale
    client_original_indices = train_dataset_big.data[
        train_dataset_big.data["client_id"] == i
    ].index

    # Converte gli indici originali in indici del subset
    client_subset_indices = [original_to_subset[idx] for idx in client_original_indices if idx in original_to_subset]

    # Crea il subset per il client
    client_data = Subset(train_dataset, client_subset_indices)
    clients.append(Client(model_cifar, i, client_data, optimizer_params))


# Baseline
server_uniform = Server(model_cifar, clients, test_dataset, validation_dataset)
hyperparameters = f"CONTRIB_BS{BATCH_SIZE}_LR{LR}_M{MOMENTUM}_WD{WEIGHT_DECAY}_J{LOCAL_STEPS}_C{C}"
server_uniform.federated_averaging(local_steps=LOCAL_STEPS, batch_size=BATCH_SIZE, num_rounds=ROUNDS, fraction_fit=C,hyperparameters=hyperparameters)

# Entropy-based experiments
#server_uniform = Server(model_cifar, clients, test_dataset, validation_dataset)
#hyperparameters = f"ENTROPY_CONTRIB_BS{BATCH_SIZE}_LR{LR}_M{MOMENTUM}_WD{WEIGHT_DECAY}_J{LOCAL_STEPS}_C{C}_ALPHA{ALPHA}"
#server_uniform.federated_averaging(local_steps=LOCAL_STEPS, batch_size=BATCH_SIZE, num_rounds=ROUNDS, fraction_fit=C, alpha=ALPHA, hyperparameters=hyperparameters)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to ./data/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:15<00:00, 10.9MB/s]
# Extracting ./data/cifar-100-python.tar.gz to ./data
# Files already downloaded and verified
# No checkpoint found, Starting now...
# Round 10/2000 - Loss: 4.6049, Accuracy: 0.0132
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_10_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 20/2000 - Loss: 4.6040, Accuracy: 0.0138
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_20_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 30/2000 - Loss: 4.6032, Accuracy: 0.0136
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_30_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 40/2000 - Loss: 4.6020, Accuracy: 0.0134
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_40_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 50/2000 - Loss: 4.6009, Accuracy: 0.0148
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_50_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 60/2000 - Loss: 4.5994, Accuracy: 0.0163
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_60_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 70/2000 - Loss: 4.5976, Accuracy: 0.0177
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_70_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 80/2000 - Loss: 4.5957, Accuracy: 0.0190
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_80_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 90/2000 - Loss: 4.5932, Accuracy: 0.0209
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_90_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 100/2000 - Loss: 4.5902, Accuracy: 0.0220
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_100_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 110/2000 - Loss: 4.5866, Accuracy: 0.0227
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_110_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 120/2000 - Loss: 4.5817, Accuracy: 0.0251
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_120_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 130/2000 - Loss: 4.5758, Accuracy: 0.0264
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_130_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 140/2000 - Loss: 4.5677, Accuracy: 0.0295
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_140_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 150/2000 - Loss: 4.5574, Accuracy: 0.0303
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_150_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 160/2000 - Loss: 4.5440, Accuracy: 0.0311
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_160_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 170/2000 - Loss: 4.5261, Accuracy: 0.0298
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_170_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 180/2000 - Loss: 4.5017, Accuracy: 0.0328
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_180_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 190/2000 - Loss: 4.4704, Accuracy: 0.0331
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_190_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 200/2000 - Loss: 4.4283, Accuracy: 0.0363
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_200_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 210/2000 - Loss: 4.3753, Accuracy: 0.0406
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_210_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 220/2000 - Loss: 4.3182, Accuracy: 0.0475
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_220_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 230/2000 - Loss: 4.2611, Accuracy: 0.0514
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_230_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 240/2000 - Loss: 4.2099, Accuracy: 0.0570
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_240_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 250/2000 - Loss: 4.1789, Accuracy: 0.0611
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_250_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 260/2000 - Loss: 4.1252, Accuracy: 0.0702
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_260_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 270/2000 - Loss: 4.0951, Accuracy: 0.0805
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_270_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 280/2000 - Loss: 4.0944, Accuracy: 0.0710
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_280_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 290/2000 - Loss: 4.0648, Accuracy: 0.0778
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_290_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 300/2000 - Loss: 4.0371, Accuracy: 0.0832
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_300_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 310/2000 - Loss: 4.0426, Accuracy: 0.0820
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_310_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 320/2000 - Loss: 4.0267, Accuracy: 0.0876
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_320_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 330/2000 - Loss: 4.0027, Accuracy: 0.0909
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_330_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 340/2000 - Loss: 3.9892, Accuracy: 0.0941
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_340_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 350/2000 - Loss: 4.0248, Accuracy: 0.0785
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_350_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 360/2000 - Loss: 3.9748, Accuracy: 0.0979
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_360_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 370/2000 - Loss: 3.9594, Accuracy: 0.0972
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_370_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 380/2000 - Loss: 3.9458, Accuracy: 0.1019
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_380_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 390/2000 - Loss: 3.9964, Accuracy: 0.0784
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_390_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 400/2000 - Loss: 3.9375, Accuracy: 0.1023
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_400_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 410/2000 - Loss: 3.9022, Accuracy: 0.1092
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_410_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 420/2000 - Loss: 3.9075, Accuracy: 0.1068
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_420_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 430/2000 - Loss: 3.9074, Accuracy: 0.1070
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_430_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 440/2000 - Loss: 3.8886, Accuracy: 0.1104
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_440_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 450/2000 - Loss: 3.8705, Accuracy: 0.1178
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_450_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 460/2000 - Loss: 3.8716, Accuracy: 0.1167
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_460_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 470/2000 - Loss: 3.8826, Accuracy: 0.1112
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_470_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 480/2000 - Loss: 3.8353, Accuracy: 0.1200
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_480_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 490/2000 - Loss: 3.8729, Accuracy: 0.1109
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_490_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 500/2000 - Loss: 3.8111, Accuracy: 0.1282
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_500_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 510/2000 - Loss: 3.8082, Accuracy: 0.1246
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_510_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 520/2000 - Loss: 3.7942, Accuracy: 0.1292
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_520_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 530/2000 - Loss: 3.7913, Accuracy: 0.1307
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_530_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 540/2000 - Loss: 3.7689, Accuracy: 0.1321
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_540_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 550/2000 - Loss: 3.7985, Accuracy: 0.1195
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_550_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 560/2000 - Loss: 3.7603, Accuracy: 0.1343
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_560_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 570/2000 - Loss: 3.7340, Accuracy: 0.1403
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_570_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 580/2000 - Loss: 3.7345, Accuracy: 0.1368
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_580_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 590/2000 - Loss: 3.7110, Accuracy: 0.1427
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_590_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 600/2000 - Loss: 4.2292, Accuracy: 0.0726
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_600_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 610/2000 - Loss: 3.6927, Accuracy: 0.1465
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_610_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 620/2000 - Loss: 3.6951, Accuracy: 0.1482
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_620_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 630/2000 - Loss: 3.7441, Accuracy: 0.1329
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_630_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 640/2000 - Loss: 3.6661, Accuracy: 0.1514
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_640_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 650/2000 - Loss: 3.6626, Accuracy: 0.1515
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_650_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 660/2000 - Loss: 3.6529, Accuracy: 0.1516
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_660_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 670/2000 - Loss: 3.6335, Accuracy: 0.1554
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_670_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 680/2000 - Loss: 3.6395, Accuracy: 0.1538
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_680_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 690/2000 - Loss: 3.6140, Accuracy: 0.1617
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_690_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 700/2000 - Loss: 3.5967, Accuracy: 0.1623
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_700_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 710/2000 - Loss: 3.5885, Accuracy: 0.1640
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_710_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 720/2000 - Loss: 3.7525, Accuracy: 0.1201
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_720_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 730/2000 - Loss: 3.5823, Accuracy: 0.1679
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_730_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 740/2000 - Loss: 3.5581, Accuracy: 0.1729
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_740_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 750/2000 - Loss: 3.5602, Accuracy: 0.1674
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_750_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 760/2000 - Loss: 3.5319, Accuracy: 0.1806
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_760_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 770/2000 - Loss: 3.5747, Accuracy: 0.1677
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_770_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 780/2000 - Loss: 3.5488, Accuracy: 0.1680
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_780_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 790/2000 - Loss: 3.5286, Accuracy: 0.1690
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_790_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 800/2000 - Loss: 3.5377, Accuracy: 0.1685
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_800_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 810/2000 - Loss: 3.5132, Accuracy: 0.1746
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_810_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 820/2000 - Loss: 3.5405, Accuracy: 0.1748
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_820_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 830/2000 - Loss: 3.4837, Accuracy: 0.1860
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_830_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 840/2000 - Loss: 3.5175, Accuracy: 0.1756
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_840_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 850/2000 - Loss: 3.4894, Accuracy: 0.1847
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_850_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 860/2000 - Loss: 3.4739, Accuracy: 0.1876
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_860_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 870/2000 - Loss: 3.5965, Accuracy: 0.1571
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_870_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 880/2000 - Loss: 3.4577, Accuracy: 0.1913
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_880_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 890/2000 - Loss: 3.4677, Accuracy: 0.1853
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_890_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 900/2000 - Loss: 3.4408, Accuracy: 0.1936
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_900_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 910/2000 - Loss: 3.4533, Accuracy: 0.1863
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_910_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 920/2000 - Loss: 3.4225, Accuracy: 0.1955
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_920_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 930/2000 - Loss: 3.4301, Accuracy: 0.1899
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_930_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 940/2000 - Loss: 3.4137, Accuracy: 0.1934
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_940_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 950/2000 - Loss: 3.4455, Accuracy: 0.1895
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_950_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 960/2000 - Loss: 3.4012, Accuracy: 0.1998
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_960_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 970/2000 - Loss: 3.4070, Accuracy: 0.1984
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_970_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 980/2000 - Loss: 3.3868, Accuracy: 0.2001
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_980_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 990/2000 - Loss: 3.3829, Accuracy: 0.2033
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_990_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1000/2000 - Loss: 3.3705, Accuracy: 0.2027
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1000_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1010/2000 - Loss: 3.3627, Accuracy: 0.2045
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1010_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1020/2000 - Loss: 3.3704, Accuracy: 0.2065
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1020_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1030/2000 - Loss: 3.3593, Accuracy: 0.2111
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1030_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1040/2000 - Loss: 3.3515, Accuracy: 0.2092
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1040_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1050/2000 - Loss: 3.3720, Accuracy: 0.2076
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1050_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1060/2000 - Loss: 3.4474, Accuracy: 0.1859
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1060_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1070/2000 - Loss: 3.3432, Accuracy: 0.2134
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1070_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1080/2000 - Loss: 3.3342, Accuracy: 0.2134
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1080_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1090/2000 - Loss: 3.3301, Accuracy: 0.2183
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1090_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1100/2000 - Loss: 3.3485, Accuracy: 0.2084
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1100_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1110/2000 - Loss: 3.3038, Accuracy: 0.2188
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1110_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1120/2000 - Loss: 3.3126, Accuracy: 0.2186
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1120_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1130/2000 - Loss: 3.3174, Accuracy: 0.2199
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1130_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1140/2000 - Loss: 3.3041, Accuracy: 0.2198
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1140_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1150/2000 - Loss: 3.2904, Accuracy: 0.2206
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1150_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1160/2000 - Loss: 3.2900, Accuracy: 0.2245
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1160_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1170/2000 - Loss: 3.2864, Accuracy: 0.2211
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1170_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1180/2000 - Loss: 3.2817, Accuracy: 0.2277
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1180_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1190/2000 - Loss: 3.3012, Accuracy: 0.2181
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1190_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1200/2000 - Loss: 3.3467, Accuracy: 0.2126
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1200_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1210/2000 - Loss: 3.3844, Accuracy: 0.2000
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1210_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1220/2000 - Loss: 3.2967, Accuracy: 0.2161
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1220_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1230/2000 - Loss: 3.2904, Accuracy: 0.2193
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1230_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1240/2000 - Loss: 3.2324, Accuracy: 0.2334
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1240_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1250/2000 - Loss: 3.2481, Accuracy: 0.2309
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1250_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1260/2000 - Loss: 3.3544, Accuracy: 0.2059
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1260_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1270/2000 - Loss: 3.3415, Accuracy: 0.2162
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1270_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1280/2000 - Loss: 3.2555, Accuracy: 0.2316
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1280_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1290/2000 - Loss: 3.2177, Accuracy: 0.2382
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1290_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1300/2000 - Loss: 3.3154, Accuracy: 0.2170
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1300_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1310/2000 - Loss: 3.2214, Accuracy: 0.2397
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1310_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1320/2000 - Loss: 3.2289, Accuracy: 0.2327
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1320_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1330/2000 - Loss: 3.2248, Accuracy: 0.2337
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1330_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1340/2000 - Loss: 3.2145, Accuracy: 0.2343
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1340_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1350/2000 - Loss: 3.2566, Accuracy: 0.2354
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1350_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1360/2000 - Loss: 3.2754, Accuracy: 0.2249
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1360_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1370/2000 - Loss: 3.2631, Accuracy: 0.2368
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1370_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1380/2000 - Loss: 3.2194, Accuracy: 0.2376
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1380_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1390/2000 - Loss: 3.1757, Accuracy: 0.2451
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1390_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1400/2000 - Loss: 3.1807, Accuracy: 0.2411
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1400_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1410/2000 - Loss: 3.1986, Accuracy: 0.2404
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1410_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1420/2000 - Loss: 3.1719, Accuracy: 0.2454
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1420_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1430/2000 - Loss: 3.1776, Accuracy: 0.2455
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1430_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1440/2000 - Loss: 3.1744, Accuracy: 0.2464
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1440_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1450/2000 - Loss: 3.1623, Accuracy: 0.2503
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1450_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1460/2000 - Loss: 3.1642, Accuracy: 0.2497
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1460_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1470/2000 - Loss: 3.2468, Accuracy: 0.2311
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1470_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1480/2000 - Loss: 3.1828, Accuracy: 0.2503
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1480_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1490/2000 - Loss: 3.1584, Accuracy: 0.2473
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1490_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1500/2000 - Loss: 3.2088, Accuracy: 0.2458
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1500_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1510/2000 - Loss: 3.2249, Accuracy: 0.2442
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1510_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1520/2000 - Loss: 3.1538, Accuracy: 0.2512
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1520_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1530/2000 - Loss: 3.1705, Accuracy: 0.2477
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1530_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1540/2000 - Loss: 3.1388, Accuracy: 0.2543
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1540_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1550/2000 - Loss: 3.1430, Accuracy: 0.2562
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1550_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1560/2000 - Loss: 3.1575, Accuracy: 0.2498
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1560_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1570/2000 - Loss: 3.1268, Accuracy: 0.2536
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1570_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1580/2000 - Loss: 3.2284, Accuracy: 0.2373
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1580_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1590/2000 - Loss: 3.1781, Accuracy: 0.2430
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1590_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1600/2000 - Loss: 3.1196, Accuracy: 0.2590
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1600_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1610/2000 - Loss: 3.2538, Accuracy: 0.2349
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1610_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1620/2000 - Loss: 3.1841, Accuracy: 0.2443
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1620_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1630/2000 - Loss: 3.1328, Accuracy: 0.2581
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1630_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1640/2000 - Loss: 3.1057, Accuracy: 0.2644
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1640_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1650/2000 - Loss: 3.1754, Accuracy: 0.2523
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1650_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1660/2000 - Loss: 3.0958, Accuracy: 0.2593
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1660_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1670/2000 - Loss: 3.1254, Accuracy: 0.2610
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1670_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1680/2000 - Loss: 3.1166, Accuracy: 0.2611
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1680_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1690/2000 - Loss: 3.1974, Accuracy: 0.2474
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1690_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1700/2000 - Loss: 3.1234, Accuracy: 0.2591
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1700_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1710/2000 - Loss: 3.1265, Accuracy: 0.2542
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1710_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1720/2000 - Loss: 3.1394, Accuracy: 0.2579
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1720_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1730/2000 - Loss: 3.1511, Accuracy: 0.2573
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1730_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1740/2000 - Loss: 3.1359, Accuracy: 0.2608
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1740_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1750/2000 - Loss: 3.1036, Accuracy: 0.2689
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1750_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1760/2000 - Loss: 3.1250, Accuracy: 0.2608
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1760_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1770/2000 - Loss: 3.1082, Accuracy: 0.2657
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1770_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1780/2000 - Loss: 3.2320, Accuracy: 0.2496
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1780_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1790/2000 - Loss: 3.1682, Accuracy: 0.2574
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1790_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1800/2000 - Loss: 3.1688, Accuracy: 0.2537
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1800_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1810/2000 - Loss: 3.1123, Accuracy: 0.2643
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1810_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1820/2000 - Loss: 3.1146, Accuracy: 0.2663
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1820_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1830/2000 - Loss: 3.1057, Accuracy: 0.2608
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1830_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1840/2000 - Loss: 3.1249, Accuracy: 0.2626
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1840_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1850/2000 - Loss: 3.0913, Accuracy: 0.2719
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1850_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1860/2000 - Loss: 3.0950, Accuracy: 0.2724
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1860_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1870/2000 - Loss: 3.1495, Accuracy: 0.2629
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1870_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1880/2000 - Loss: 3.1100, Accuracy: 0.2706
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1880_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1890/2000 - Loss: 3.1304, Accuracy: 0.2646
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1890_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1900/2000 - Loss: 3.1089, Accuracy: 0.2657
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1900_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1910/2000 - Loss: 3.0932, Accuracy: 0.2657
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1910_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1920/2000 - Loss: 3.1059, Accuracy: 0.2676
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1920_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1930/2000 - Loss: 3.1005, Accuracy: 0.2708
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1930_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1940/2000 - Loss: 3.0400, Accuracy: 0.2789
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1940_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1950/2000 - Loss: 3.1133, Accuracy: 0.2705
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1950_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1960/2000 - Loss: 3.0873, Accuracy: 0.2707
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1960_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1970/2000 - Loss: 3.0776, Accuracy: 0.2752
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1970_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1980/2000 - Loss: 3.0953, Accuracy: 0.2705
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1980_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 1990/2000 - Loss: 3.0575, Accuracy: 0.2823
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_1990_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth
# Round 2000/2000 - Loss: 3.1668, Accuracy: 0.2644
# Checkpoint salvato: /content/drive/My Drive/My Folder/checkpoints_contrib/Federated_Uniform/model_epoch_2000_params_CONTRIB_BS64_LR0.001_M0_WD0.0001_J4_C0.1.pth

# %%
DIR_DATA = "/content"

train_dataset = CIFAR100Dataset(DIR_DATA, split='train', sharding='eniid', K=100)

clients = train_dataset.data['client_id'].unique()
for client_id in clients:
  client_data = train_dataset.data[train_dataset.data['client_id'] == client_id]
  label_counts = client_data['label'].value_counts()

  plt.figure(figsize=(8, 4))
  label_counts.plot(kind='bar', color='skyblue', edgecolor='black')
  plt.title(f"Label Frequency for Client {client_id}, len {sum(label_counts)}")
  plt.xlabel("Label")
  plt.ylabel("Frequency")
  plt.xticks(rotation=45)
  plt.tight_layout()
  #plt.savefig(f"{CHECKPOINT_DIR}/plots/niid_{Nc}class_frequency_client_{client_id}.jpg")
  plt.show()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-100-python.tar.gz to /content/cifar-100-python.tar.gz
# 100%|██████████| 169M/169M [00:03<00:00, 49.0MB/s]
# Extracting /content/cifar-100-python.tar.gz to /content
